# %%
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker 
import pycountry_convert as pc
import folium
import branca
from datetime import datetime, timedelta,date
from scipy.interpolate import make_interp_spline, BSpline
import plotly.express as px
import json, requests


# %matplotlib inline

# %%
df_india_test = pd.io.json.json_normalize(requests.get('https://api.rootnet.in/covid19-in/stats/testing/history').json()['data']).rename(columns = {"totalIndividualsTested":"c_individualtest","totalPositiveCases":"c_positive","totalSamplesTested":"c_tests"})

# %%
df_india_test["p2t_ratio"]= np.round(100*df_india_test["c_positive"]/df_india_test["c_tests"],2)
df_india_test["positive"] = df_india_test["c_positive"].diff()
df_india_test["tests"] = df_india_test["c_tests"].diff()
df_india_test["p2t_ratio"]= np.round(100*df_india_test["positive"]/df_india_test["tests"],2)

# %%
df_india_test
# Out:
#            day  c_tests  c_individualtest  c_positive  \
# 0   2020-03-12     6500              5900          78
# 1   2020-03-18    13125             12235         150
# 2   2020-03-19    14175             13285         182
# 3   2020-03-20    15404             14514         236
# 4   2020-03-21    16911             16021         315
# 5   2020-03-22    18127             17237         396
# 6   2020-03-23    20707             19817         471
# 7   2020-03-24    22694             21804         536
# 8   2020-03-25    22928             22038         539
# 9   2020-03-27    27688             26798         691
# 10  2020-03-30    38442             37000        1334
# 11  2020-03-31    42788             41000        1733
#
#                                                source  p2t_ratio  positive  \
# 0                  Press_Release_ICMR_13March2020.pdf        NaN       NaN
# 1             ICMR_website_update_18March_6PM_IST.pdf       1.09      72.0
# 2             ICMR_website_update_19March_6PM_IST.pdf       3.05      32.0
# 3             ICMR_website_update_20March_6PM_IST.pdf       4.39      54.0
# 4             ICMR_website_update_21March_6PM_IST.pdf       5.24      79.0
# 5             ICMR_website_update_22March_6PM_IST.pdf       6.66      81.0
# 6             ICMR_website_update_23March_8PM_IST.pdf       2.91      75.0
# 7             ICMR_website_update_24March_8PM_IST.pdf       3.27      65.0
# 8            ICMR_website_update_25March_10AM_IST.pdf       1.28       3.0
# 9   https://icmr.nic.in/sites/default/files/whats_...       3.19     152.0
# 10  https://www.youtube.com/watch?v=yvJY0LuM8kQ&fe...       5.98     643.0
# 11                                   MOH announcement       9.18     399.0
#
#       tests
# 0       NaN
# 1    6625.0
# 2    1050.0
# 3    1229.0
# 4    1507.0
# 5    1216.0
# 6    2580.0
# 7    1987.0
# 8     234.0
# 9    4760.0
# 10  10754.0
# 11   4346.0

# %%
f = plt.figure(figsize=(15,10))
#f.add_subplots(111)
plt.axes(axisbelow=True)
plt.bar(df_india_test["day"],df_india_test["tests"].values[:],color="darkcyan",label="Test (Negetive)"+str())
plt.bar(df_india_test["day"],df_india_test["positive"].values[:],bottom=df_india_test["tests"].values[:]-df_india_test["positive"].values[:],color="Red",label="Test (Positive)")
plt.tick_params(size=5,labelsize = 13)
plt.tick_params(axis="x",size=5,labelsize = 13,labelrotation=60 )
plt.xlabel("Date",fontsize=18)
plt.ylabel("Test Results",fontsize=18)

plt.title("Tests in India",fontsize=20)
plt.grid(alpha=0.3)
plt.legend()
plt.savefig('out'+'Test_India.png')

# %%
df_india_test["c_tests"][-1:].values[0]
# Out:
# 42788

# %%
np.round(1000000*df_india_test["c_tests"][-1:].values[0]/1300000000,2)
# Out:
# 32.91

# %%
india_data_json = requests.get('https://api.rootnet.in/covid19-in/unofficial/covid19india.org/statewise').json()
df_india = pd.io.json.json_normalize(india_data_json['data']['statewise'])
df_india = df_india.set_index('state')
#df_india=df_india.style.background_gradient(cmap='Wistia')
df_india
# Out:
#                              confirmed  recovered  deaths  active
# state
# Maharashtra                        335         39      13     283
# Kerala                             265         26       2     237
# Tamil Nadu                         234          6       1     227
# Delhi                              152          6       2     144
# Uttar Pradesh                      116         17       2      97
# Karnataka                          110          9       3      98
# Rajasthan                          108          3       0     105
# Telangana                           97         14       6      77
# Andhra Pradesh                      87          2       0      85
# Gujarat                             87          5       6      76
# Madhya Pradesh                      86          0       6      80
# Jammu and Kashmir                   62          2       2      58
# Punjab                              46          1       4      41
# Haryana                             43         27       0      16
# West Bengal                         37          3       6      28
# Bihar                               24          0       1      23
# Chandigarh                          15          0       0      15
# Ladakh                              13          3       0      10
# Andaman and Nicobar Islands         10          0       0      10
# Chhattisgarh                         9          2       0       7
# Uttarakhand                          7          2       0       5
# Assam                               13          0       0      13
# Goa                                  5          0       0       5
# Odisha                               4          1       0       3
# Himachal Pradesh                     3          1       1       1
# Puducherry                           3          0       0       3
# Jharkhand                            1          0       0       1
# Manipur                              1          0       0       1
# Mizoram                              1          0       0       1
# Arunachal Pradesh                    0          0       0       0
# Dadra and Nagar Haveli               0          0       0       0
# Daman and Diu                        0          0       0       0
# Lakshadweep                          0          0       0       0
# Meghalaya                            0          0       0       0
# Nagaland                             0          0       0       0
# Sikkim                               0          0       0       0
# Tripura                              0          0       0       0

# %%
total = df_india.sum()
total.name = "Total"
pd.DataFrame(total).transpose().style.background_gradient(cmap='Wistia',axis=1)
# Out:
# <style  type="text/css" >
#     #T_827bef76_7434_11ea_b5b0_f8da0c7fed5arow0_col0 {
#             background-color:  #fc7f00;
#             color:  #000000;
#         }    #T_827bef76_7434_11ea_b5b0_f8da0c7fed5arow0_col1 {
#             background-color:  #eafa63;
#             color:  #000000;
#         }    #T_827bef76_7434_11ea_b5b0_f8da0c7fed5arow0_col2 {
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }    #T_827bef76_7434_11ea_b5b0_f8da0c7fed5arow0_col3 {
#             background-color:  #fd8e00;
#             color:  #000000;
#         }</style><table id="T_827bef76_7434_11ea_b5b0_f8da0c7fed5a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >confirmed</th>        <th class="col_heading level0 col1" >recovered</th>        <th class="col_heading level0 col2" >deaths</th>        <th class="col_heading level0 col3" >active</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_827bef76_7434_11ea_b5b0_f8da0c7fed5alevel0_row0" class="row_heading level0 row0" >Total</th>
#                         <td id="T_827bef76_7434_11ea_b5b0_f8da0c7fed5arow0_col0" class="data row0 col0" >1974</td>
#                         <td id="T_827bef76_7434_11ea_b5b0_f8da0c7fed5arow0_col1" class="data row0 col1" >169</td>
#                         <td id="T_827bef76_7434_11ea_b5b0_f8da0c7fed5arow0_col2" class="data row0 col2" >55</td>
#                         <td id="T_827bef76_7434_11ea_b5b0_f8da0c7fed5arow0_col3" class="data row0 col3" >1750</td>
#             </tr>
#     </tbody></table>

# %%
f = plt.figure(figsize=(15,10))
plt.axes(axisbelow=True)
#df_india_con=df_india.sort['confirmed']
plt.barh(df_india.sort_values('confirmed')["confirmed"].index[-10:],df_india.sort_values('confirmed')["confirmed"].values[-10:],color="darkcyan")
plt.tick_params(size=5,labelsize = 13)
plt.xlabel("Confirmed Cases",fontsize=18)
plt.title("Top 10 States: India (Confirmed Cases)",fontsize=20)
plt.grid(alpha=0.3)
plt.savefig('out'+'Top 10 States_India (Confirmed Cases).png')

# %%
df_india.corr().style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow0_col1 {
#             background-color:  #fb7d5d;
#             color:  #000000;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow0_col2 {
#             background-color:  #fedccd;
#             color:  #000000;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow0_col3 {
#             background-color:  #6b010e;
#             color:  #f1f1f1;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow1_col0 {
#             background-color:  #fc9b7c;
#             color:  #000000;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow1_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow1_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow1_col3 {
#             background-color:  #fcb79c;
#             color:  #000000;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow2_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow2_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow2_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow2_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow3_col0 {
#             background-color:  #6b010e;
#             color:  #f1f1f1;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow3_col1 {
#             background-color:  #fcab8f;
#             color:  #000000;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow3_col2 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow3_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }</style><table id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >confirmed</th>        <th class="col_heading level0 col1" >recovered</th>        <th class="col_heading level0 col2" >deaths</th>        <th class="col_heading level0 col3" >active</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5alevel0_row0" class="row_heading level0 row0" >confirmed</th>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow0_col1" class="data row0 col1" >0.772493</td>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow0_col2" class="data row0 col2" >0.650328</td>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow0_col3" class="data row0 col3" >0.996073</td>
#             </tr>
#             <tr>
#                         <th id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5alevel0_row1" class="row_heading level0 row1" >recovered</th>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow1_col0" class="data row1 col0" >0.772493</td>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow1_col1" class="data row1 col1" >1</td>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow1_col2" class="data row1 col2" >0.59454</td>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow1_col3" class="data row1 col3" >0.716233</td>
#             </tr>
#             <tr>
#                         <th id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5alevel0_row2" class="row_heading level0 row2" >deaths</th>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow2_col0" class="data row2 col0" >0.650328</td>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow2_col1" class="data row2 col1" >0.59454</td>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow2_col2" class="data row2 col2" >1</td>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow2_col3" class="data row2 col3" >0.61436</td>
#             </tr>
#             <tr>
#                         <th id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5alevel0_row3" class="row_heading level0 row3" >active</th>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow3_col0" class="data row3 col0" >0.996073</td>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow3_col1" class="data row3 col1" >0.716233</td>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow3_col2" class="data row3 col2" >0.61436</td>
#                         <td id="T_8a8d9b74_7439_11ea_bb71_f8da0c7fed5arow3_col3" class="data row3 col3" >1</td>
#             </tr>
#     </tbody></table>

# %%
# Adding Location data (Latitude,Longitude)
locations = {
    "Kerala" : [10.8505,76.2711],
    "Maharashtra" : [19.7515,75.7139],
    "Karnataka": [15.3173,75.7139],
    "Telangana": [18.1124,79.0193],
    "Uttar Pradesh": [26.8467,80.9462],
    "Rajasthan": [27.0238,74.2179],
    "Gujarat":[22.2587,71.1924],
    "Delhi" : [28.7041,77.1025],
    "Punjab":[31.1471,75.3412],
    "Tamil Nadu": [11.1271,78.6569],
    "Haryana": [29.0588,76.0856],
    "Madhya Pradesh":[22.9734,78.6569],
    "Jammu and Kashmir":[33.7782,76.5762],
    "Ladakh": [34.1526,77.5770],
    "Andhra Pradesh":[15.9129,79.7400],
    "West Bengal": [22.9868,87.8550],
    "Bihar": [25.0961,85.3131],
    "Chhattisgarh":[21.2787,81.8661],
    "Chandigarh":[30.7333,76.7794],
    "Uttarakhand":[30.0668,79.0193],
    "Himachal Pradesh":[31.1048,77.1734],
    "Goa": [15.2993,74.1240],
    "Odisha":[20.9517,85.0985],
    "Andaman and Nicobar Islands": [11.7401,92.6586],
    "Puducherry":[11.9416,79.8083],
    "Manipur":[24.6637,93.9063],
    "Mizoram":[23.1645,92.9376],
    "Assam":[26.2006,92.9376],
    "Meghalaya":[25.4670,91.3662],
    "Tripura":[23.9408,91.9882],
    "Arunachal Pradesh":[28.2180,94.7278],
    "Jharkhand" : [23.6102,85.2799],
    "Nagaland": [26.1584,94.5624],
    "Sikkim": [27.5330,88.5122],
    "Dadra and Nagar Haveli":[20.1809,73.0169],
    "Lakshadweep":[10.5667,72.6417],
    "Daman and Diu":[20.4283,72.8397]    
}
df_india["Lat"] = ""
df_india["Long"] = ""
for index in df_india.index :
    df_india.loc[df_india.index == index,"Lat"] = locations[index][0]
    df_india.loc[df_india.index == index,"Long"] = locations[index][1]

# %%
url = "https://raw.githubusercontent.com/Subhash9325/GeoJson-Data-of-Indian-States/master/Indian_States"
state_json = requests.get(url).json()
india = folium.Map(location=[23,80], zoom_start=4,max_zoom=6,min_zoom=4,height=500,width="80%")
for i in range(0,len(df_india[df_india['confirmed']>0].index)):
    folium.Circle(
        location=[df_india.iloc[i]['Lat'], df_india.iloc[i]['Long']],
        tooltip = "<h5 style='text-align:center;font-weight: bold'>"+df_india.iloc[i].name+"</h5>"+
                    "<hr style='margin:10px;'>"+
                    "<ul style='color: #444;list-style-type:circle;align-item:left;padding-left:20px;padding-right:20px'>"+
        "<li>Confirmed: "+str(df_india.iloc[i]['confirmed'])+"</li>"+
        "<li>Active:   "+str(df_india.iloc[i]['active'])+"</li>"+
        "<li>Recovered:   "+str(df_india.iloc[i]['recovered'])+"</li>"+
        "<li>Deaths:   "+str(df_india.iloc[i]['deaths'])+"</li>"+
        
        "<li>Mortality Rate:   "+str(np.round(df_india.iloc[i]['deaths']/(df_india.iloc[i]['confirmed']+1)*100,2))+"</li>"+
        "</ul>"
        ,
        radius=(int(np.log2(df_india.iloc[i]['confirmed']+1)))*15000,
        color='#ff6600',
        fill_color='#ff8533',
        fill=True).add_to(india)
india
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
